# %% [markdown]
# ## **The Sparks Foundation- GRIP JAN21- Data Science & Business Analytics**
# **Task-3 Exploratory Data Analysis**
#
# Author : PRINCE S

# %% [markdown]
# **Importing necessary library**

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
#from plotnine import *
import warnings
#warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# **Reading Dataset**

# %%
from google.colab import files 


uploaded = files.upload()

data = pd.read_csv('SampleSuperstore.csv')
data.head()
# Out:
#      <input type="file" id="files-9e280277-2fd5-4714-80bb-cd114aeb9537" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e280277-2fd5-4714-80bb-cd114aeb9537">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SampleSuperstore.csv to SampleSuperstore.csv
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
data.shape
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# **Checking and Droping Duplicate Data**

# %%
data.duplicated().sum()
data.drop_duplicates(inplace = True)
data.head()
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# **Data Visualization**  Discount , Profit , Sale, Quantity

# %%
data1.hist(bins=50 ,figsize=(20,15))
plt.show();

# %% [markdown]
# **Count Plot For Every State**

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=data1['State'])
plt.xticks(rotation=90)
plt.title("STATE")
plt.show()

# %% [markdown]
# State wise sales distribution & State wise profit distribution

# %%
fig,ax=plt.subplots(figsize=(30,12))
x=data['State']
y=data['Sales']
ax.set_xlabel('State')
ax.set_ylabel('Sales')
ax.set_title('State wise Sales distribution')

fig.autofmt_xdate()
ax.bar(x,y)
plt.show()
fig,ax=plt.subplots(figsize=(30,12))
x=data['State']
y=data['Profit']
ax.set_xlabel('State')
ax.set_ylabel('Profit')
ax.set_title('State wise Profit distribution')

fig.autofmt_xdate()
ax.bar(x,y)
plt.show()

# %% [markdown]
# Region wise sales distribution & Region wise profit distribution

# %%
fig,ax=plt.subplots(figsize=(30,12))
x=data['Region']
y=data['Sales']
ax.set_xlabel('Region')
ax.set_ylabel('Sales')
ax.set_title('Region wise Sales distribution')

fig.autofmt_xdate()
ax.bar(x,y)
plt.show()
fig,ax=plt.subplots(figsize=(30,12))
x=data['Region']
y=data['Profit']
ax.set_xlabel('Region')
ax.set_ylabel('Profit')
ax.set_title('Region wise Profit distribution')

fig.autofmt_xdate()
ax.bar(x,y)
plt.show()

# %% [markdown]
# Region wise category classification

# %%
plt.figure(figsize = (30, 12))
sns.countplot(x = 'Category', hue = 'Region', data = data, palette = 'rocket')
plt.xticks(rotation = 45, fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('Categories', fontsize = 25)
plt.ylabel('', fontsize = 20)
plt.legend(loc = 5, fontsize = 20)

# %% [markdown]
# Category wise sales distribution &
# Category wise profit distribution

# %%
fig,ax=plt.subplots(figsize=(30,12))
x=data['Category']
y=data['Sales']
ax.set_xlabel('Category')
ax.set_ylabel('Sales')
ax.set_title('Category wise Sales distribution')

fig.autofmt_xdate()
ax.bar(x,y)
plt.show()


plt.figure(figsize=(17,8))
sns.barplot(x='Category',y='Profit',data=data,ci=False)

# %% [markdown]
# Sub-category wise sales distribution & profit distribution

# %%
fig,ax=plt.subplots(figsize=(30,12))
x=data['Sub-Category']
y=data['Sales']
ax.set_xlabel('Sub-Category')
ax.set_ylabel('Sales')
ax.set_title('Sub-Category wise Sales distribution')

fig.autofmt_xdate()
ax.bar(x,y)
plt.show()

plt.figure(figsize=(17,8))
sns.barplot(x='Sub-Category',y='Profit',data=data,ci=False)

# %% [markdown]
# **Corelations between variables**

# %%
col=['Postal Code']
data1=data.drop(columns=col,axis=1)
data1.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %% [markdown]
# **Sales VS Profit Scatter Plot**

# %%
fig, ax = plt.subplots(figsize = (10 , 6))
ax.scatter(data1["Sales"] , data1["Profit"])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
ax.set_title('Sales vs Profit')
plt.show()
